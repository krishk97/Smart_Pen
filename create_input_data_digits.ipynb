# %%
## Input is a Pandas table of ax, ay, az, gx, gy, gz over time
## Output is a np table of ax, ay, az, gx, gy, gz and selected features
import numpy as np
import pandas as pd
from scipy import stats, fft, fftpack
import serial
import ast
import signal
import atexit

PORT = 'COM6'
BAUDRATE = 115200

'''
Class that handles comms with smart pen
'''
class read_serial: 
    def __init__(self, port_name, baudrate):
            self.port_name = port_name
            self.baudrate = baudrate
            print('Ready to rock and roll!')
            
    def init_comms(self): 
        self.ser = serial.Serial(self.port_name)
        self.ser.baudrate = self.baudrate

        receive_data = False
        data = []
        while True: 
        # begin communication   
            try:
                line = self.ser.readline()[:-2] # Strip Line feed and carriage return
                line = line.decode("utf-8") # Decode UTF-8 Bytes

                if (line == '{'):
                    receive_data = True
                    
                elif (line == '}'):
                    #self.print_data(data)
                    #receive_data = False
                    #data = []
                    self.handle_exit()
                    return data
        
                elif (receive_data):
                    try:
                        data.append(ast.literal_eval(line))
                    except SyntaxError:
                        pass
                                   
        # end communication with KeyboardInterrupt
            except KeyboardInterrupt:
                print('User keyboard exit')
                self.handle_exit()
                break 
                                   
    def print_data(self,data):
            print('Sample Received: \n')
            data = np.asarray(data)
            print(data)
                  
    def handle_exit(self):
            print('Closed Serial Port')
            self.ser.close()
                  
read = read_serial(PORT,BAUDRATE)
data = read.init_comms()
print(data)
# Out:
# Ready to rock and roll!
# Sample Received:
#
# [[  344 12160 -8092 -4976  -425   877]
#  [ 1156 12444 -8740 -4992  -149   -88]
#  [ 1680 13712 -8340 -4960    73    91]
#  [  840 12028 -8360 -4976   261   211]
#  [ 1252 12604 -8276 -4944  -487   165]
#  [ 1464 12512 -8420 -4976  -177   278]
#  [ 1444 12484 -8652 -4992  -324  -119]
#  [  712 12440 -8080 -4944  -426   -32]
#  [ 1144 12380 -8452 -4960  -196   459]
#  [ 1396 12444 -8548 -4928  -432     4]
#  [  652 12164 -8056 -4944  -354   133]
#  [ 1324 12584 -8348 -4992  -275   547]
#  [ 1008 11980 -8480 -4976  -372   254]
#  [  932 12808 -8136 -5008  -162   888]
#  [ 1372 11888 -9132 -4992  -187   194]
#  [ 1348 12900 -8328 -4992  -593  -226]
#  [  780 12084 -8288 -4992  -302   -21]
#  [ 1372 12708 -7824 -5008  -653   711]
#  [ 1292 12104 -8604 -4976   -50   375]
#  [ 1316 12600 -8352 -4976  -466   108]
#  [  904 12304 -8300 -5024  -351   224]
#  [ 1184 12440 -8416 -4992  -247   463]
#  [ 1096 12284 -8460 -4960  -512   162]
#  [  808 12312 -8228 -4960  -321   293]
#  [ 1092 12412 -8452 -4992  -523   511]
#  [  424 11984 -8012 -4992  -374   524]
#  [ 1900 12996 -8508 -4976  -390  1142]]
# Closed Serial Port
# [[344, 12160, -8092, -4976, -425, 877], [1156, 12444, -8740, -4992, -149, -88], [1680, 13712, -8340, -4960, 73, 91], [840, 12028, -8360, -4976, 261, 211], [1252, 12604, -8276, -4944, -487, 165], [1464, 12512, -8420, -4976, -177, 278], [1444, 12484, -8652, -4992, -324, -119], [712, 12440, -8080, -4944, -426, -32], [1144, 12380, -8452, -4960, -196, 459], [1396, 12444, -8548, -4928, -432, 4], [652, 12164, -8056, -4944, -354, 133], [1324, 12584, -8348, -4992, -275, 547], [1008, 11980, -8480, -4976, -372, 254], [932, 12808, -8136, -5008, -162, 888], [1372, 11888, -9132, -4992, -187, 194], [1348, 12900, -8328, -4992, -593, -226], [780, 12084, -8288, -4992, -302, -21], [1372, 12708, -7824, -5008, -653, 711], [1292, 12104, -8604, -4976, -50, 375], [1316, 12600, -8352, -4976, -466, 108], [904, 12304, -8300, -5024, -351, 224], [1184, 12440, -8416, -4992, -247, 463], [1096, 12284, -8460, -4960, -512, 162], [808, 12312, -8228, -4960, -321, 293], [1092, 12412, -8452, -4992, -523, 511], [424, 11984, -8012, -4992, -374, 524], [1900, 12996, -8508, -4976, -390, 1142]]

# %%
# Input is a Pandas table of ax, ay, az, gx, gy, gz over time
## Output is a np table of ax, ay, az, gx, gy, gz and selected features
import numpy as np
import pandas as pd
from scipy import stats, fft, fftpack



def pd_to_abt_np(dataframe):
    '''
    
    '''
    sensor_data = dataframe.to_numpy()
    print(sensor_data.shape)
    #want to see (# of samples,6)
    
    means = np.mean(sensor_data, axis=0)
    ranges = np.ptp(sensor_data, axis = 0)
    stds = np.std(sensor_data, axis=0)
    moment_3 = stats.moment(sensor_data, moment=3, axis=0)
    
    dcts = fftpack.dct(sensor_data, axis=0)
    sorted_dcts = np.sort(dcts, axis=0)
    max_dcts = sorted_dcts[0]
    second_max_dcts = sorted_dcts[1]
    
    ffts = fft(sensor_data, axis=0)
    sorted_ffts = np.sort(ffts,axis=0)
    max_ffts = sorted_ffts[0]
    second_max_ffts = sorted_ffts[1]
    
    to_be_stacked = (means, ranges, stds, moment_3, max_dcts, second_max_dcts, 
                    max_ffts, second_max_ffts)
    
    abt_table = np.vstack(to_be_stacked)
    
    return abt_table

# %%
#output random digit between 0-9

from random import randint
from random import seed

seed(2493)

def generate_randint():
    while True:
        yield randint(0,9)

# %%
num_samples = 100

def record_training_data():
    '''
    tell user to write down digit
    record raw values
    perform feature extraction
    pickle the data
    '''
    
    random_integer = generate_randint()
    while i in xrange(num_samples):
        integer = next(random_integer)
        print('Write {}'.format(integer))
