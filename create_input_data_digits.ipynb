# %%
## Input is a Pandas table of ax, ay, az, gx, gy, gz over time
## Output is a np table of ax, ay, az, gx, gy, gz and selected features
import numpy as np
import pandas as pd
from scipy import stats, fft, fftpack
import serial
import ast
import signal
import atexit

PORT = 'COM6'
BAUDRATE = 115200

'''
Class that handles comms with smart pen
'''
class read_serial: 
    def __init__(self, port_name, baudrate):
            self.port_name = port_name
            self.baudrate = baudrate
            print('Ready to rock and roll!')
            
    def init_comms(self): 
        self.ser = serial.Serial(self.port_name)
        self.ser.baudrate = self.baudrate
    
    def read_data(self):
        receive_data = False
        data = []
        # begin reading data from pen
        while True: 
            try:
                line = self.ser.readline()[:-2] # Strip Line feed and carriage return
                line = line.decode("utf-8") # Decode UTF-8 Bytes

                if (line == '{'):
                    receive_data = True
                    
                elif (line == '}'):
                    self.print_data(data)
                    receive_data = False
                    self.close_comms()
                    return data
        
                elif (receive_data):
                    try:
                        data.append(ast.literal_eval(line))
                    except SyntaxError:
                        pass
                                   
        # end communication with KeyboardInterrupt
            except KeyboardInterrupt:
                print('User keyboard exit')
                self.close_comms()
                break 
                
    def print_data(self,data):
            print('Sample Received: \n')
            data = np.asarray(data)
            print(data)
                  
    def close_comms(self):
            print('Closed Serial Port')
            self.ser.close()
                  
read = read_serial(PORT,BAUDRATE)
read.init_comms()
data = read.read_data()

print('recorded data: \n', data)
# Out:
# Ready to rock and roll!
# Sample Received:
#
# [[   632  12420  -8208  -4960    -56   1195]
#  [  2508  11688  -9316  -4944   -380   -341]
#  [   524  12416  -7540  -4944   -655   -509]
#  [  1144  12356  -8476  -4944    229   1359]
#  [  2472  12100  -9164  -4944   -576   -486]
#  [     0  12280  -7600  -4944   -480    -27]
#  [  2188  12448  -8856  -4960    209   1216]
#  [  1556  11736  -9096  -4960   -829   -596]
#  [   488  12752  -7840  -4928    -64    577]
#  [  2220  11936  -9040  -4944   -345    822]
#  [  1124  12140  -8364  -4944   -527   -638]
#  [  1076  12756  -8072  -4944   -131    893]
#  [  1932  11760  -9160  -4944   -392     77]
#  [   896  12724  -7968  -4944   -394   -274]
#  [  1268  12224  -8596  -4928   -125   1046]
#  [  1932  12020  -8732  -4944   -436   -408]
#  [   504  12500  -7764  -4976   -421    332]
#  [  1752  12004  -8924  -4944    -79    867]
#  [  1780  12252  -8684  -4928   -606   -477]
#  [   628  12412  -7920  -4928   -204    546]
#  [  2020  12192  -8904  -4928   -281    394]
#  [  1000  12240  -8368  -4960   -530   -312]
#  [  1204  12544  -8336  -4960   -125    773]
#  [  2052  12036  -8952  -4928   -401    132]
#  [  1072  12312  -8208  -4960   -434      4]
#  [  1540  12428  -8472  -4944   -139    698]
#  [  1520  11940  -8756  -4944   -526    -72]
#  [  1040  12628  -8228  -4944   -267    354]
#  [  1568  12012  -8688  -4912   -319    482]
#  [  1260  12384  -8676  -4944   -409    -48]
#  [  1148  12292  -8376  -4944   -428    674]
#  [   748  12040  -9084  -4960   -376    202]
#  [   452   9852 -10336  -4928   -526   1192]]
# Closed Serial Port
# recorded data:
#  [[632, 12420, -8208, -4960, -56, 1195], [2508, 11688, -9316, -4944, -380, -341], [524, 12416, -7540, -4944, -655, -509], [1144, 12356, -8476, -4944, 229, 1359], [2472, 12100, -9164, -4944, -576, -486], [0, 12280, -7600, -4944, -480, -27], [2188, 12448, -8856, -4960, 209, 1216], [1556, 11736, -9096, -4960, -829, -596], [488, 12752, -7840, -4928, -64, 577], [2220, 11936, -9040, -4944, -345, 822], [1124, 12140, -8364, -4944, -527, -638], [1076, 12756, -8072, -4944, -131, 893], [1932, 11760, -9160, -4944, -392, 77], [896, 12724, -7968, -4944, -394, -274], [1268, 12224, -8596, -4928, -125, 1046], [1932, 12020, -8732, -4944, -436, -408], [504, 12500, -7764, -4976, -421, 332], [1752, 12004, -8924, -4944, -79, 867], [1780, 12252, -8684, -4928, -606, -477], [628, 12412, -7920, -4928, -204, 546], [2020, 12192, -8904, -4928, -281, 394], [1000, 12240, -8368, -4960, -530, -312], [1204, 12544, -8336, -4960, -125, 773], [2052, 12036, -8952, -4928, -401, 132], [1072, 12312, -8208, -4960, -434, 4], [1540, 12428, -8472, -4944, -139, 698], [1520, 11940, -8756, -4944, -526, -72], [1040, 12628, -8228, -4944, -267, 354], [1568, 12012, -8688, -4912, -319, 482], [1260, 12384, -8676, -4944, -409, -48], [1148, 12292, -8376, -4944, -428, 674], [748, 12040, -9084, -4960, -376, 202], [452, 9852, -10336, -4928, -526, 1192]]

# %%
# Input is a Pandas table of ax, ay, az, gx, gy, gz over time
## Output is a np table of ax, ay, az, gx, gy, gz and selected features
import numpy as np
import pandas as pd
from scipy import stats, fft, fftpack



def pd_to_abt_np(dataframe):
    '''
    
    '''
    sensor_data = dataframe.to_numpy()
    print(sensor_data.shape)
    #want to see (# of samples,6)
    
    means = np.mean(sensor_data, axis=0)
    ranges = np.ptp(sensor_data, axis = 0)
    stds = np.std(sensor_data, axis=0)
    moment_3 = stats.moment(sensor_data, moment=3, axis=0)
    
    dcts = fftpack.dct(sensor_data, axis=0)
    sorted_dcts = np.sort(dcts, axis=0)
    max_dcts = sorted_dcts[0]
    second_max_dcts = sorted_dcts[1]
    
    ffts = fft(sensor_data, axis=0)
    sorted_ffts = np.sort(ffts,axis=0)
    max_ffts = sorted_ffts[0]
    second_max_ffts = sorted_ffts[1]
    
    to_be_stacked = (means, ranges, stds, moment_3, max_dcts, second_max_dcts, 
                    max_ffts, second_max_ffts)
    
    abt_table = np.vstack(to_be_stacked)
    
    return abt_table

# %%
#output random digit between 0-9

from random import randint
from random import seed

seed(2493)

def generate_randint():
    while True:
        yield randint(0,9)

# %%
num_samples = 100

def record_training_data():
    '''
    tell user to write down digit
    record raw values
    perform feature extraction
    pickle the data
    '''
    
    random_integer = generate_randint()
    while i in xrange(num_samples):
        integer = next(random_integer)
        print('Write {}'.format(integer))
